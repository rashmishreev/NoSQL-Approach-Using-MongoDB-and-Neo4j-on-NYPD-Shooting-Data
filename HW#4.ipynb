# %%
# hw_4

# %%
import pymongo 
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb+srv://g4mongo:g4mongodb@nyshootingcluster.yq7k5n5.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
nycrime_df = pd.read_csv("NYPD_Shooting_Incident_Data__Historic_cleaned.csv")

# %%
nycrime_df.head()
# Out:
#    INCIDENT_KEY OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  JURISDICTION_CODE  \
# 0     227950661     5/9/21    2:50:00      BRONX        41                  2
# 1     225438895    3/10/21    7:30:00  MANHATTAN        28                  0
# 2     232193235    8/13/21    1:00:00     QUEENS       109                  0
# 3     225168410     3/4/21   13:17:00      BRONX        40                  2
# 4     231965278     8/7/21   23:57:00      BRONX        42                  2
#
#                LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX  \
# 0  MULTI DWELL - PUBLIC HOUS                     True          25-44        M
# 1    MULTI DWELL - APT BUILD                    False          25-44        M
# 2             BAR/NIGHT CLUB                     True          18-24        M
# 3  MULTI DWELL - PUBLIC HOUS                    False          25-44        M
# 4  MULTI DWELL - PUBLIC HOUS                     True            <18        M
#
# ...

# %%
nycrime_df.tail()
# Out:
#       INCIDENT_KEY OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 7238     143158588    5/23/15   16:00:00   BROOKLYN        75
# 7239      85235457    6/12/12   22:00:00      BRONX        41
# 7240      10038648     1/9/06   18:26:00  MANHATTAN        23
# 7241      92311769    8/26/13   13:25:00   BROOKLYN        75
# 7242      77443443    2/25/11    1:12:00   BROOKLYN        81
#
#       JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 7238                  0    MULTI DWELL - APT BUILD                    False
# 7239                  0    MULTI DWELL - APT BUILD                    False
# 7240                  2  MULTI DWELL - PUBLIC HOUS                    False
# 7241                  0             SMALL MERCHANT                     True
# 7242                  0    MULTI DWELL - APT BUILD                    False
#
#      PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 7238          25-44        M     BLACK         18-24       M
# ...

# %%
data0 = nycrime_df.to_dict (orient = "records")

# %%
data0
# Out:
# [{'INCIDENT_KEY': 227950661,
#   'OCCUR_DATE': '5/9/21',
#   'OCCUR_TIME': '2:50:00',
#   'BORO': 'BRONX',
#   'PRECINCT': 41,
#   'JURISDICTION_CODE': 2,
#   'LOCATION_DESC': 'MULTI DWELL - PUBLIC HOUS',
#   'STATISTICAL_MURDER_FLAG': True,
#   'PERP_AGE_GROUP': '25-44',
#   'PERP_SEX': 'M',
#   'PERP_RACE': 'BLACK',
#   'VIC_AGE_GROUP': '25-44',
#   'VIC_SEX': 'M',
#   'VIC_RACE': 'BLACK HISPANIC',
#   'X_COORD_CD': 1014642.0,
#   'Y_COORD_CD': 240068.0,
#   'Latitude': 40.82556269,
#   'Longitude': -73.89018729,
#   'Lon_Lat': 'POINT (-73.89018728699995 40.82556269400004)'},
#  {'INCIDENT_KEY': 225438895,
#   'OCCUR_DATE': '3/10/21',
#   'OCCUR_TIME': '7:30:00',
#   'BORO': 'MANHATTAN',
#   'PRECINCT': 28,
#   'JURISDICTION_CODE': 0,
#   'LOCATION_DESC': 'MULTI DWELL - APT BUILD',
#   'STATISTICAL_MURDER_FLAG': False,
#   'PERP_AGE_GROUP': '25-44',
#   'PERP_SEX': 'M',
#   'PERP_RACE': 'BLACK',
#   'VIC_AGE_GROUP': '18-24',
#   'VIC_SEX': 'M',
#   'VIC_RACE': 'BLACK',
# ...

# %%
db = client["nycDb"]

# %%
print (db)
# Out:
# Database(MongoClient(host=['ac-0ua2b1i-shard-00-00.yq7k5n5.mongodb.net:27017', 'ac-0ua2b1i-shard-00-01.yq7k5n5.mongodb.net:27017', 'ac-0ua2b1i-shard-00-02.yq7k5n5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-13ucd7-shard-0', tls=True), 'nycDb')

# %%
db.nypdIncidentCol.insert_many(data0)
